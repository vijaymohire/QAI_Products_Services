# %% [markdown]
# # **QAI_Agile_Product_Owner Framework**
#
# 1) Initializing your homegrown products (QAI Processor, OS, Ops, PLM, Robotics, Transducers, Datacenter).
#
# 2) Simulating roles, phases, and layers (Business → Planning → Execution → Feedback → Manufacturing → Release).
#
# 3) Showing data flow through each layer (requirements → backlog → increments → prototypes → release).
#
# 4) Using Agile sprint iterations with refinement loops.
#
# 5) Printing milestones with clear checkpoints

# %%
# QAI_Agile_Product_Owner Framework Simulation with QAI Products (Colab Ready)

import matplotlib.pyplot as plt
import numpy as np
import random

# ============================
# 1. Initialize Homegrown QAI Products
# ============================
QAI_products = {
    "QAI_Processor": {"status": "Initialized", "role": "Hybrid HW/SW Execution"},
    "QAI_OS": {"status": "Initialized", "role": "Quantum-Classical OS"},
    "QAI_Ops": {"status": "Initialized", "role": "Unified Ops & Metrics"},
    "QAI_PLM": {"status": "Initialized", "role": "Product Lifecycle Management"},
    "QAI_Robotics": {"status": "Initialized", "role": "Agile Manufacturing"},
    "QAI_Transducers": {"status": "Initialized", "role": "Quantum-Classical Bridges"},
    "QAI_Datacenter": {"status": "Initialized", "role": "Hybrid R&D & HPC Infra"}
}

print("=== Homegrown QAI Products Initialized ===")
for k, v in QAI_products.items():
    print(f"{k} → {v['status']} ({v['role']})")

# ============================
# 2. Define Roles, Layers, and Phases
# ============================
roles = [
    "Client", "Product Owner", "Scrum Master", "Developers",
    "R&D Scientists", "Systems Engineer (P.Eng)", "Fab Engineer",
    "Managers", "External Stakeholders"
]

layers = [
    "Business & Strategy (QAI_PLM)",
    "Planning & Roadmap (QAI_PLM, QAI_Ops)",
    "Agile Execution (QAI_Processor, QAI_OS)",
    "Delivery & Feedback (QAI_Ops)",
    "Systems & Blueprint (QAI_PLM)",
    "Manufacturing & Prototype (QAI_Robotics, QAI_Transducers)",
    "Continuous Learning (QAI_Ops, QAI_Datacenter)"
]

milestones = [
    "🚀 Vision Charter Approved",
    "📌 PI Planning Completed",
    "⚡ First Working Increment",
    "🛠 Prototype Manufactured",
    "🏁 Major Release Delivered"
]

# ============================
# 3. Agile Sprint Simulation
# ============================
sprints = 4
backlog_items = ["Quantum-Classical Bridge", "Cryogenic Stability", "Post-Quantum Security Layer", "Agile Manufacturing Workflow"]

print("\n=== Agile Sprint Simulation ===")
for sprint in range(1, sprints+1):
    print(f"\n--- Sprint {sprint} ---")
    # Select random backlog items
    selected_items = random.sample(backlog_items, k=2)
    print(f"Backlog Selected: {selected_items}")
    print("Roles Active: Product Owner, Scrum Master, Developers, Scientists")
    print("Processes: Refinement → Build → Test → Review")
    print("Data Flow: Backlog → Increment → Feedback")

    # Feedback simulation
    feedback_score = random.randint(60,95)
    print(f"Client Feedback Score: {feedback_score}%")
    if feedback_score < 75:
        print("🔄 Refinement Required → Backlog updated for next sprint")
    else:
        print("✅ Accepted Increment → Moves closer to release")

# ============================
# 4. KPI Tracking (Dummy Data)
# ============================
kpis = {
    "Business": 80,
    "Planning": 72,
    "Execution": 85,
    "Delivery": 78,
    "Blueprint": 70,
    "Manufacturing": 65,
    "Learning": 90
}

# Bar Chart for KPIs
plt.figure(figsize=(8,5))
plt.bar(kpis.keys(), kpis.values(), color="#66b2ff")
plt.ylabel("KPI Achievement (%)")
plt.title("QAI APO KPI Dashboard")
plt.xticks(rotation=30)
plt.show()

# ============================
# 5. Manufacturing Yield Simulation
# ============================
iterations = np.arange(1,6)
yield_rate = [50, 65, 70, 80, 88]

plt.figure(figsize=(8,5))
plt.plot(iterations, yield_rate, marker="o", linestyle="-", color="green")
plt.xlabel("Prototype Iteration")
plt.ylabel("Yield (%)")
plt.title("QAI Manufacturing Yield Trend")
plt.show()

# ============================
# 6. Milestone Timeline
# ============================
timeline = [1,2,3,4,5]
plt.figure(figsize=(10,2))
plt.hlines(1, 1, 5, color="gray", linewidth=2)
plt.plot(timeline, [1]*len(timeline), "o", color="blue")
for x, label in zip(timeline, milestones):
    plt.text(x, 1.05, label, ha="center", fontsize=9, weight="bold")
plt.ylim(0.8,1.2)
plt.axis("off")
plt.title("QAI APO Release Milestones")
plt.show()

print("\n=== Simulation Complete ===")
print("Data moved across layers → Products used → Roles active → Feedback loops until Major Release.")
# Out:
# === Homegrown QAI Products Initialized ===
# QAI_Processor → Initialized (Hybrid HW/SW Execution)
# QAI_OS → Initialized (Quantum-Classical OS)
# QAI_Ops → Initialized (Unified Ops & Metrics)
# QAI_PLM → Initialized (Product Lifecycle Management)
# QAI_Robotics → Initialized (Agile Manufacturing)
# QAI_Transducers → Initialized (Quantum-Classical Bridges)
# QAI_Datacenter → Initialized (Hybrid R&D & HPC Infra)
#
# === Agile Sprint Simulation ===
#
# --- Sprint 1 ---
# Backlog Selected: ['Agile Manufacturing Workflow', 'Quantum-Classical Bridge']
# Roles Active: Product Owner, Scrum Master, Developers, Scientists
# Processes: Refinement → Build → Test → Review
# Data Flow: Backlog → Increment → Feedback
# Client Feedback Score: 75%
# ✅ Accepted Increment → Moves closer to release
#
# --- Sprint 2 ---
# Backlog Selected: ['Agile Manufacturing Workflow', 'Post-Quantum Security Layer']
# Roles Active: Product Owner, Scrum Master, Developers, Scientists
# ...

# %% [markdown]
# **Concept and execution by Bhadale IT, code generated by ChatGPT**
